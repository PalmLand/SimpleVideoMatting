# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tqdm
import cv2
import os
import random
import keras
import seaborn as sns

# %%
root = './'
white = '/whiteBG_resize/'
other = '/whitenoBG_resize/'

white_dirs = os.listdir(root+white)
other_dirs = os.listdir(root+other)

# %%
plt.figure(figsize=(12,24))
for i in range(4):
    plt.subplot(1,4,i+1)
    img = cv2.imread(root+white+white_dirs[i])
    plt.imshow(img)
    plt.title('white : 1')
    plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,24))
for i in range(4):
    plt.subplot(1,4,i+1)
    img = cv2.imread(root+other+other_dirs[i])
    plt.imshow(img)
    plt.title('other : 0')
    plt.tight_layout()
plt.show()

# %%
dim1,dim2 = [],[]

for img_file in os.listdir(root+white):
    img = plt.imread(root+white+img_file)
    d1, d2, colors = img.shape
    dim1.append(d1)
    dim2.append(d2)
    
sns.jointplot(dim1, dim2)

print(np.mean(dim1))#131.58001306335728
print(np.mean(dim2))#131.3424776834313
# Out:
# D:\A\Python\Software\Anaconda\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# 320.0
# 320.0

# %%
from tensorflow.keras.preprocessing.image import img_to_array

data = []
labels = []
 
for img in white_dirs:
    try:
        img_read = plt.imread(root+white+img)
        img_resize = cv2.resize(img_read,(100,100))
        img_array = img_to_array(img_resize)#将图片转换为数组格式
        data.append(img_array)
        labels.append(1)
    except:
        None

for img in other_dirs:
    try:
        img_read = plt.imread(root+other+img)
        img_resize = cv2.resize(img_read,(100,100))
        img_array = img_to_array(img_resize)
        data.append(img_array)
        labels.append(0)
    except:
        None

# %%
from sklearn.utils import shuffle

# 将数据和标签变量转换为Numpy格式
image_data = np.array(data)
labels = np.array(labels)

# 将被随机数据重新分配到它们的原始变量中
idx = np.arange(image_data.shape[0])
np.random.shuffle(idx)
image_data = image_data[idx]
labels = labels[idx]

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# 将数据转换为32位数据以保存
def prep_dataset(X,y):
    X_prep = X.astype('float32')/255
    y_prep = to_categorical(np.array(y))
    return (X_prep,y_prep)

# stratify按照labels比例划分数据集
X_tr, X_ts, Y_tr, Y_ts = train_test_split(image_data,labels,test_size=0.15,shuffle=True,stratify=labels,random_state=42)
X_ts, X_val, Y_ts, Y_val = train_test_split(X_ts,Y_ts,test_size=0.5,stratify=Y_ts,random_state=42)

X_tr, Y_tr = prep_dataset(X_tr, Y_tr)
X_val, Y_val = prep_dataset(X_val, Y_val)
X_ts, Y_ts = prep_dataset(X_ts, Y_ts)

# %%
from tensorflow.keras import models, layers
from tensorflow.keras.callbacks import EarlyStopping

model = models.Sequential()

#Input + Conv 1 + ReLU + Max Pooling
model.add(layers.Conv2D(32,(5,5),activation='relu',padding='same',input_shape=X_tr.shape[1:]))
model.add(layers.MaxPool2D(strides=4))
model.add(layers.BatchNormalization())

# Conv 2 + ReLU + Max Pooling
model.add(layers.Conv2D(64,(5,5),padding='same',activation='relu'))
model.add(layers.MaxPool2D(strides=2))
model.add(layers.BatchNormalization())

# Conv 3 + ReLU + Max Pooling
model.add(layers.Conv2D(128,(3,3),padding='same',activation='relu'))
model.add(layers.MaxPool2D(strides=2))
model.add(layers.BatchNormalization())

# Conv 4 + ReLU + Max Pooling
model.add(layers.Conv2D(256,(3,3),dilation_rate=(2,2),padding='same',activation='relu'))
model.add(layers.Conv2D(256,(3,3),activation='relu'))
model.add(layers.MaxPool2D(strides=2))
model.add(layers.BatchNormalization())

# Fully Connected + ReLU
model.add(layers.Flatten())
model.add(layers.Dense(300,activation='relu'))
model.add(layers.Dense(100,activation='relu'))

#Output
model.add(layers.Dense(2,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 100, 100, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 25, 25, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 25, 25, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 25, 25, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 12, 12, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 256)         295168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 256)         590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 2, 256)         1024
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 300)               307500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 1,352,522
# Trainable params: 1,351,562
# Non-trainable params: 960
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# 早停法旨在解决epoch数量需要手动设置的问题
# 它也可以被视为一种能够避免网络发生过拟合的正则化方法（与L1/L2权重衰减和丢弃法类似）
# patience容忍3个epoch内都没有提升
es = EarlyStopping(monitor='val_acc',mode='max',patience=3,verbose=1)
history = model.fit(X_tr,Y_tr,
                   epochs=20,
                   batch_size=50,
                   validation_data=(X_val,Y_val),
                   callbacks=[es])
# Out:
# Epoch 1/20
# 36/36 [==============================] - 7s 191ms/step - loss: 0.3541 - accuracy: 0.8476 - val_loss: 1.6404 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 2/20
# 36/36 [==============================] - 7s 190ms/step - loss: 0.2160 - accuracy: 0.9036 - val_loss: 2.7157 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 3/20
# 36/36 [==============================] - 7s 184ms/step - loss: 0.2267 - accuracy: 0.9025 - val_loss: 3.2093 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 4/20
# 36/36 [==============================] - 7s 182ms/step - loss: 0.1622 - accuracy: 0.9367 - val_loss: 2.9723 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 5/20
# 36/36 [==============================] - 7s 184ms/step - loss: 0.1579 - accuracy: 0.9406 - val_loss: 3.7503 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 6/20
# 36/36 [==============================] - 7s 184ms/step - loss: 0.1563 - accuracy: 0.9389 - val_loss: 3.3878 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 7/20
# 36/36 [==============================] - 7s 184ms/step - loss: 0.1192 - accuracy: 0.9546 - val_loss: 3.0905 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 8/20
# 36/36 [==============================] - 7s 187ms/step - loss: 0.1249 - accuracy: 0.9535 - val_loss: 3.3368 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 9/20
# 36/36 [==============================] - 7s 185ms/step - loss: 0.0955 - accuracy: 0.9619 - val_loss: 3.2188 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 10/20
# 36/36 [==============================] - 7s 184ms/step - loss: 0.1053 - accuracy: 0.9585 - val_loss: 3.9413 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 11/20
# 36/36 [==============================] - 7s 185ms/step - loss: 0.0862 - accuracy: 0.9697 - val_loss: 3.7757 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 12/20
# 36/36 [==============================] - 7s 183ms/step - loss: 0.0617 - accuracy: 0.9770 - val_loss: 2.8192 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 13/20
# 36/36 [==============================] - 7s 183ms/step - loss: 0.0526 - accuracy: 0.9793 - val_loss: 5.0329 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 14/20
# 36/36 [==============================] - 7s 186ms/step - loss: 0.0822 - accuracy: 0.9714 - val_loss: 1.5176 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 15/20
# 36/36 [==============================] - 7s 187ms/step - loss: 0.0509 - accuracy: 0.9838 - val_loss: 4.7256 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 16/20
# 36/36 [==============================] - 7s 186ms/step - loss: 0.0633 - accuracy: 0.9765 - val_loss: 0.5302 - val_accuracy: 0.8291
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 17/20
# 36/36 [==============================] - 7s 186ms/step - loss: 0.0713 - accuracy: 0.9725 - val_loss: 0.5261 - val_accuracy: 0.8291
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 18/20
# 36/36 [==============================] - 7s 184ms/step - loss: 0.0588 - accuracy: 0.9770 - val_loss: 2.0202 - val_accuracy: 0.5063
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 19/20
# 36/36 [==============================] - 7s 185ms/step - loss: 0.0530 - accuracy: 0.9787 - val_loss: 2.0118 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 20/20
# 36/36 [==============================] - 7s 187ms/step - loss: 0.0440 - accuracy: 0.9843 - val_loss: 3.1777 - val_accuracy: 0.5000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy

# %%
import seaborn as sns

fig, ax = plt.subplots(2,1,figsize=(12,10))
fig.suptitle('Train evaluation')

sns.lineplot(ax=ax[0],x=np.arange(0,len(history.history['accuracy'])),y=history.history['accuracy'])
sns.lineplot(ax=ax[0],x=np.arange(0,len(history.history['accuracy'])),y=history.history['val_accuracy'])

ax[0].legend(['Train','Validation'])
ax[0].set_title('Accuracy')

sns.lineplot(ax=ax[1],x=np.arange(0,len(history.history['loss'])),y=history.history['loss'])
sns.lineplot(ax=ax[1],x=np.arange(0,len(history.history['loss'])),y=history.history['val_loss'])

ax[1].legend(['Train','Validation'])
ax[1].set_title('Loss')

plt.show()

# %%
# 构建一个混淆矩阵
from sklearn.metrics import confusion_matrix, accuracy_score

Y_pred = model.predict(X_ts)

Y_pred = np.argmax(Y_pred, axis=1)
Y_ts_r = np.argmax(Y_ts, axis=1)
conf_mat = confusion_matrix(Y_ts_r,Y_pred)

sns.set_style(style='white')
plt.figure(figsize=(12,8))
heatmap = sns.heatmap(conf_mat,vmin=np.min(conf_mat.all()), vmax=np.max(conf_mat), annot=True,fmt='d', annot_kws={"fontsize":20},cmap='Spectral')
heatmap.set_title('Confusion Matrix Heatmap\n Is the cell infected?', fontdict={'fontsize':15}, pad=12)
heatmap.set_xlabel('Predicted',fontdict={'fontsize':14})
heatmap.set_ylabel('Actual',fontdict={'fontsize':14})
heatmap.set_xticklabels(['NO','YES'], fontdict={'fontsize':12})
heatmap.set_yticklabels(['NO','YES'], fontdict={'fontsize':12})
plt.show()

print('-Acuracy achieved: {:.2f}%\n-Accuracy by model was: {:.2f}%\n-Accuracy by validation was: {:.2f}%'.
      format(accuracy_score(Y_ts_r,Y_pred)*100,(history.history['accuracy'][-1])*100,(history.history['val_accuracy'][-1])*100))
# Out:
# -Acuracy achieved: 50.32%
# -Accuracy by model was: 98.43%
# -Accuracy by validation was: 50.00%

# %%
index=0
index_errors= []

for label, predict in zip(Y_ts_r,Y_pred):
    if label != predict:
        index_errors.append(index)
    index +=1

plt.figure(figsize=(20,8))

for i,img_index in zip(range(1,17),random.sample(index_errors,k=16)):
    plt.subplot(2,8,i)
    plt.imshow(np.reshape(255*X_ts[img_index], (100,100,3)))
    plt.title('Actual: '+str(Y_ts_r[img_index])+' Predict: '+str(Y_pred[img_index]))
plt.show()

# %%
test = 'D:/A/Python/Datasets/CV/Segmentation/PersonSeg/background_resize/'
test_dirs = os.listdir(test)
plt.figure(figsize=(12,24))
for i in range(4):
    plt.subplot(1,4,i+1)
    img = cv2.imread(test+test_dirs[i])
    plt.imshow(img)
    plt.title('white : 1')
    plt.tight_layout()
plt.show()

print(np.mean(dim1))#131.58001306335728
print(np.mean(dim2))#131.3424776834313

test_data = []
test_labels = []
for img in test_dirs:
    try:
        img_read = plt.imread(test+img)
        img_resize = cv2.resize(img_read,(100,100))
        img_array = img_to_array(img_resize)#将图片转换为数组格式
        test_data.append(img_array)
        test_labels.append(1)
    except:
        None
        
# 将数据和标签变量转换为Numpy格式
test_image_data = np.array(test_data)
test_labels = np.array(test_labels)

# 将被随机数据重新分配到它们的原始变量中
test_idx = np.arange(test_image_data.shape[0])
np.random.shuffle(test_idx)
test_image_data = test_image_data[test_idx]
test_labels = test_labels[test_idx]

test_X,test_Y = prep_dataset(test_image_data, test_labels)
predict_Y = model.predict(test_X)
predict_Y = np.argmax(predict_Y, axis=1)
y = predict_Y.tolist()
len(y)

# 返回一个0,1数组中1的数量
def num_one(source_array):
    count = 0
    for x in source_array:
        if x == 1:
            count += 1
    return count
num_one(y)
# Out:
# 320.0
# 320.0
